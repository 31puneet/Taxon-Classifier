# %%
import sys, os
sys.path.insert(0, os.path.abspath("../src"))
from evaluation.visualize import plot_tsne, plot_k_comparison, plot_poison_comparison, plot_depth_curve

# %%
plot_tsne(k=15);
# Out:
# Running TruncatedSVD (1M -> 50 dims)...
# Running t-SNE (50 -> 2 dims)...

# %%
plot_k_comparison();

# %%
plot_poison_comparison();

# %%
plot_depth_curve(k=15);
